# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("train.csv")
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
first_five = data.head()
first_five
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
x = data['x'].values
y = data['y'].values

# %%
X = x.reshape(-1,1)
Y = y.reshape(-1,1)

x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=100)

print(f"x_train shape [{x_train.shape}")
print(f"y_train shape [{y_train.shape}")
print(f"x_test shape [{x_test.shape}")
print(f"y_test shape [{y_test.shape}")
# x_test
x_train,y_train
# Out:
# x_train shape [(560, 1)
# y_train shape [(560, 1)
# x_test shape [(140, 1)
# y_test shape [(140, 1)
# (array([[3.00000000e+01],
#         [1.00000000e+00],
#         [4.00000000e+01],
#         [8.40000000e+01],
#         [6.10000000e+01],
#         [5.90000000e+01],
#         [9.40000000e+01],
#         [6.00000000e+00],
#         [8.10000000e+01],
#         [4.30000000e+01],
#         [9.60000000e+01],
#         [6.00000000e+01],
#         [7.40000000e+01],
#         [1.30000000e+01],
#         [2.90000000e+01],
#         [8.90000000e+01],
#         [5.80000000e+01],
#         [1.40000000e+01],
#         [9.50000000e+01],
#         [4.20000000e+01],
#         [3.53015737e+03],
#         [1.00000000e+01],
#         [5.00000000e+01],
#         [9.70000000e+01],
#         [3.70000000e+01],
#         [1.70000000e+01],
#         [3.20000000e+01],
#         [7.50000000e+01],
#         [5.00000000e+01],
#         [5.00000000e+01],
#         [1.00000000e+01],
#         [2.60000000e+01],
#         [8.10000000e+01],
#         [9.00000000e+00],
#         [8.00000000e+00],
#         [1.40000000e+01],
#         [8.60000000e+01],
#         [3.60000000e+01],
#         [5.00000000e+00],
#         [5.00000000e+00],
#         [2.60000000e+01],
#         [5.20000000e+01],
#         [4.10000000e+01],
#         [4.80000000e+01],
#         [8.90000000e+01],
#         [1.00000000e+02],
#         [9.90000000e+01],
#         [9.00000000e+01],
#         [7.20000000e+01],
#         [5.10000000e+01],
#         [3.70000000e+01],
#         [1.40000000e+01],
#         [1.00000000e+01],
#         [8.60000000e+01],
#         [4.20000000e+01],
#         [8.10000000e+01],
#         [9.60000000e+01],
#         [8.10000000e+01],
#         [7.10000000e+01],
#         [8.90000000e+01],
#         [5.00000000e+00],
#         [8.90000000e+01],
#         [5.80000000e+01],
#         [6.10000000e+01],
#         [6.60000000e+01],
#         [5.00000000e+01],
#         [7.90000000e+01],
#         [1.60000000e+01],
#         [2.50000000e+01],
#         [1.10000000e+01],
#         [2.40000000e+01],
#         [7.50000000e+01],
#         [5.80000000e+01],
#         [1.90000000e+01],
#         [7.80000000e+01],
#         [3.80000000e+01],
#         [9.00000000e+01],
#         [5.60000000e+01],
#         [2.50000000e+01],
#         [7.50000000e+01],
#         [9.50000000e+01],
#         [5.40000000e+01],
#         [3.00000000e+01],
#         [2.50000000e+01],
#         [2.10000000e+01],
#         [7.90000000e+01],
#         [5.70000000e+01],
#         [6.20000000e+01],
#         [2.40000000e+01],
#         [9.80000000e+01],
#         [3.70000000e+01],
#         [9.50000000e+01],
#         [2.60000000e+01],
#         [4.70000000e+01],
#         [2.40000000e+01],
#         [1.60000000e+01],
#         [4.80000000e+01],
#         [8.60000000e+01],
#         [4.90000000e+01],
#         [1.80000000e+01],
#         [3.00000000e+01],
#         [5.80000000e+01],
#         [5.10000000e+01],
#         [5.00000000e+01],
#         [6.00000000e+01],
#         [6.20000000e+01],
#         [7.80000000e+01],
#         [8.00000000e+00],
#         [5.60000000e+01],
#         [3.00000000e+00],
#         [7.50000000e+01],
#         [8.50000000e+01],
#         [9.10000000e+01],
#         [7.60000000e+01],
#         [4.50000000e+01],
#         [2.80000000e+01],
#         [3.40000000e+01],
#         [6.10000000e+01],
#         [2.90000000e+01],
#         [3.80000000e+01],
#         [4.00000000e+00],
#         [2.70000000e+01],
#         [9.20000000e+01],
#         [9.30000000e+01],
#         [4.30000000e+01],
#         [9.70000000e+01],
#         [5.80000000e+01],
#         [3.50000000e+01],
#         [4.50000000e+01],
#         [7.50000000e+01],
#         [1.00000000e+00],
#         [4.80000000e+01],
#         [6.70000000e+01],
#         [1.60000000e+01],
#         [8.90000000e+01],
#         [9.00000000e+01],
#         [3.10000000e+01],
#         [3.40000000e+01],
#         [1.20000000e+01],
#         [2.00000000e+01],
#         [8.60000000e+01],
#         [0.00000000e+00],
#         [3.60000000e+01],
#         [4.60000000e+01],
#         [5.10000000e+01],
#         [7.00000000e+01],
#         [8.20000000e+01],
#         [1.60000000e+01],
#         [7.90000000e+01],
#         [6.00000000e+00],
#         [4.20000000e+01],
#         [5.80000000e+01],
#         [8.30000000e+01],
#         [7.00000000e+00],
#         [1.20000000e+01],
#         [6.00000000e+01],
#         [6.20000000e+01],
#         [6.80000000e+01],
#         [5.50000000e+01],
#         [4.40000000e+01],
#         [5.00000000e+01],
#         [4.40000000e+01],
#         [4.70000000e+01],
#         [7.10000000e+01],
#         [4.30000000e+01],
#         [7.00000000e+01],
#         [5.30000000e+01],
#         [6.70000000e+01],
#         [6.80000000e+01],
#         [2.10000000e+01],
#         [8.50000000e+01],
#         [1.90000000e+01],
#         [7.10000000e+01],
#         [6.30000000e+01],
#         [4.70000000e+01],
#         [7.70000000e+01],
#         [5.00000000e+01],
#         [1.50000000e+01],
#         [4.20000000e+01],
#         [1.90000000e+01],
#         [9.90000000e+01],
#         [5.10000000e+01],
#         [7.60000000e+01],
#         [5.40000000e+01],
#         [6.80000000e+01],
#         [8.00000000e+00],
#         [9.70000000e+01],
#         [5.00000000e+01],
#         [2.40000000e+01],
#         [6.10000000e+01],
#         [8.10000000e+01],
#         [5.30000000e+01],
#         [2.40000000e+01],
#         [8.30000000e+01],
#         [2.90000000e+01],
#         [7.50000000e+01],
#         [4.90000000e+01],
#         [3.00000000e+01],
#         [1.70000000e+01],
#         [9.80000000e+01],
#         [1.00000000e+00],
#         [9.00000000e+01],
#         [2.80000000e+01],
#         [3.90000000e+01],
#         [8.00000000e+01],
#         [4.20000000e+01],
#         [9.00000000e+00],
#         [2.30000000e+01],
#         [9.40000000e+01],
#         [4.20000000e+01],
#         [7.40000000e+01],
#         [4.40000000e+01],
#         [1.20000000e+01],
#         [7.40000000e+01],
#         [2.90000000e+01],
#         [9.80000000e+01],
#         [9.30000000e+01],
#         [5.70000000e+01],
#         [8.70000000e+01],
#         [9.40000000e+01],
#         [3.80000000e+01],
#         [7.50000000e+01],
#         [9.20000000e+01],
#         [7.00000000e+00],
#         [3.40000000e+01],
#         [8.10000000e+01],
#         [9.30000000e+01],
#         [9.00000000e+01],
#         [7.40000000e+01],
#         [9.10000000e+01],
#         [1.00000000e+02],
#         [9.10000000e+01],
#         [3.50000000e+01],
#         [1.90000000e+01],
#         [6.20000000e+01],
#         [0.00000000e+00],
#         [4.40000000e+01],
#         [3.00000000e+01],
#         [4.90000000e+01],
#         [2.20000000e+01],
#         [9.30000000e+01],
#         [8.70000000e+01],
#         [7.60000000e+01],
#         [9.10000000e+01],
#         [7.50000000e+01],
#         [7.80000000e+01],
#         [8.60000000e+01],
#         [5.90000000e+01],
#         [5.10000000e+01],
#         [9.50000000e+01],
#         [1.00000000e+02],
#         [9.00000000e+00],
#         [2.00000000e+01],
#         [9.00000000e+01],
#         [8.60000000e+01],
#         [2.30000000e+01],
#         [3.00000000e+00],
#         [4.10000000e+01],
#         [3.20000000e+01],
#         [4.20000000e+01],
#         [2.10000000e+01],
#         [1.90000000e+01],
#         [1.90000000e+01],
#         [5.60000000e+01],
#         [4.90000000e+01],
#         [5.40000000e+01],
#         [9.10000000e+01],
#         [9.20000000e+01],
#         [1.30000000e+01],
#         [9.80000000e+01],
#         [9.20000000e+01],
#         [2.00000000e+00],
#         [5.20000000e+01],
#         [3.60000000e+01],
#         [3.90000000e+01],
#         [9.00000000e+01],
#         [7.30000000e+01],
#         [4.60000000e+01],
#         [3.00000000e+00],
#         [3.40000000e+01],
#         [8.00000000e+01],
#         [1.30000000e+01],
#         [6.90000000e+01],
#         [0.00000000e+00],
#         [5.30000000e+01],
#         [2.70000000e+01],
#         [4.90000000e+01],
#         [1.00000000e+02],
#         [9.70000000e+01],
#         [2.80000000e+01],
#         [2.90000000e+01],
#         [3.10000000e+01],
#         [5.80000000e+01],
#         [4.20000000e+01],
#         [9.90000000e+01],
#         [4.70000000e+01],
#         [3.40000000e+01],
#         [8.50000000e+01],
#         [9.00000000e+01],
#         [7.00000000e+01],
#         [7.40000000e+01],
#         [5.00000000e+00],
#         [5.00000000e+00],
#         [5.90000000e+01],
#         [5.00000000e+00],
#         [1.00000000e+01],
#         [2.50000000e+01],
#         [5.10000000e+01],
#         [8.40000000e+01],
#         [5.80000000e+01],
#         [9.80000000e+01],
#         [8.80000000e+01],
#         [1.60000000e+01],
#         [1.60000000e+01],
#         [6.70000000e+01],
#         [8.80000000e+01],
#         [7.00000000e+01],
#         [6.50000000e+01],
#         [8.90000000e+01],
#         [5.80000000e+01],
#         [7.70000000e+01],
#         [2.60000000e+01],
#         [2.50000000e+01],
#         [1.70000000e+01],
#         [1.80000000e+01],
#         [4.80000000e+01],
#         [1.40000000e+01],
#         [2.50000000e+01],
#         [2.50000000e+01],
#         [2.40000000e+01],
#         [1.20000000e+01],
#         [2.40000000e+01],
#         [4.40000000e+01],
#         [2.20000000e+01],
#         [3.10000000e+01],
#         [5.70000000e+01],
#         [2.00000000e+01],
#         [2.70000000e+01],
#         [5.40000000e+01],
#         [4.90000000e+01],
#         [8.60000000e+01],
#         [1.00000000e+00],
#         [5.50000000e+01],
#         [6.70000000e+01],
#         [6.80000000e+01],
#         [9.70000000e+01],
#         [8.80000000e+01],
#         [5.40000000e+01],
#         [1.70000000e+01],
#         [4.90000000e+01],
#         [7.00000000e+01],
#         [1.90000000e+01],
#         [9.30000000e+01],
#         [1.00000000e+02],
#         [2.90000000e+01],
#         [4.00000000e+01],
#         [5.00000000e+01],
#         [8.10000000e+01],
#         [5.20000000e+01],
#         [9.10000000e+01],
#         [3.00000000e+00],
#         [2.40000000e+01],
#         [7.70000000e+01],
#         [6.80000000e+01],
#         [2.20000000e+01],
#         [4.50000000e+01],
#         [2.10000000e+01],
#         [9.80000000e+01],
#         [3.70000000e+01],
#         [7.30000000e+01],
#         [1.80000000e+01],
#         [5.80000000e+01],
#         [1.50000000e+01],
#         [4.50000000e+01],
#         [4.90000000e+01],
#         [6.10000000e+01],
#         [7.50000000e+01],
#         [4.80000000e+01],
#         [2.20000000e+01],
#         [2.10000000e+01],
#         [4.80000000e+01],
#         [2.10000000e+01],
#         [6.70000000e+01],
#         [6.40000000e+01],
#         [7.00000000e+01],
#         [3.60000000e+01],
#         [2.70000000e+01],
#         [4.90000000e+01],
#         [3.40000000e+01],
#         [5.00000000e+00],
#         [6.80000000e+01],
#         [8.80000000e+01],
#         [5.40000000e+01],
#         [2.50000000e+01],
#         [1.00000000e+01],
#         [2.10000000e+01],
#         [9.50000000e+01],
#         [2.60000000e+01],
#         [8.80000000e+01],
#         [3.50000000e+01],
#         [8.90000000e+01],
#         [9.30000000e+01],
#         [7.30000000e+01],
#         [3.20000000e+01],
#         [4.40000000e+01],
#         [4.10000000e+01],
#         [8.00000000e+00],
#         [3.50000000e+01],
#         [1.00000000e+02],
#         [6.30000000e+01],
#         [2.60000000e+01],
#         [1.30000000e+01],
#         [1.00000000e+02],
#         [1.60000000e+01],
#         [6.20000000e+01],
#         [7.30000000e+01],
#         [6.50000000e+01],
#         [1.00000000e+01],
#         [1.10000000e+01],
#         [3.00000000e+00],
#         [4.00000000e+00],
#         [3.20000000e+01],
#         [3.50000000e+01],
#         [9.90000000e+01],
#         [1.00000000e+02],
#         [9.50000000e+01],
#         [4.80000000e+01],
#         [6.80000000e+01],
#         [5.50000000e+01],
#         [8.40000000e+01],
#         [4.90000000e+01],
#         [2.90000000e+01],
#         [8.30000000e+01],
#         [7.70000000e+01],
#         [7.00000000e+00],
#         [4.10000000e+01],
#         [5.40000000e+01],
#         [3.80000000e+01],
#         [8.50000000e+01],
#         [4.00000000e+00],
#         [6.80000000e+01],
#         [6.00000000e+01],
#         [8.70000000e+01],
#         [2.80000000e+01],
#         [9.00000000e+00],
#         [9.80000000e+01],
#         [6.40000000e+01],
#         [6.90000000e+01],
#         [5.00000000e+01],
#         [2.10000000e+01],
#         [3.50000000e+01],
#         [7.80000000e+01],
#         [7.10000000e+01],
#         [9.50000000e+01],
#         [5.30000000e+01],
#         [5.40000000e+01],
#         [0.00000000e+00],
#         [5.00000000e+01],
#         [4.30000000e+01],
#         [2.60000000e+01],
#         [3.40000000e+01],
#         [9.50000000e+01],
#         [1.60000000e+01],
#         [1.50000000e+01],
#         [3.30000000e+01],
#         [5.10000000e+01],
#         [5.80000000e+01],
#         [7.20000000e+01],
#         [5.50000000e+01],
#         [9.70000000e+01],
#         [7.00000000e+00],
#         [1.60000000e+01],
#         [8.70000000e+01],
#         [9.30000000e+01],
#         [8.60000000e+01],
#         [3.60000000e+01],
#         [4.80000000e+01],
#         [4.40000000e+01],
#         [8.40000000e+01],
#         [8.10000000e+01],
#         [4.00000000e+00],
#         [4.90000000e+01],
#         [3.90000000e+01],
#         [4.80000000e+01],
#         [4.60000000e+01],
#         [2.60000000e+01],
#         [7.00000000e+00],
#         [7.40000000e+01],
#         [5.50000000e+01],
#         [8.00000000e+01],
#         [5.40000000e+01],
#         [7.20000000e+01],
#         [2.10000000e+01],
#         [3.90000000e+01],
#         [2.60000000e+01],
#         [2.00000000e+00],
#         [6.10000000e+01],
#         [6.10000000e+01],
#         [5.00000000e+00],
#         [9.40000000e+01],
#         [1.00000000e+02],
#         [1.10000000e+01],
#         [4.70000000e+01],
#         [3.10000000e+01],
#         [2.70000000e+01],
#         [3.10000000e+01],
#         [3.90000000e+01],
#         [2.40000000e+01],
#         [1.60000000e+01],
#         [3.70000000e+01],
#         [8.00000000e+00],
#         [1.20000000e+01],
#         [9.30000000e+01],
#         [7.30000000e+01],
#         [4.00000000e+00],
#         [4.60000000e+01],
#         [2.20000000e+01],
#         [6.50000000e+01],
#         [9.10000000e+01],
#         [9.00000000e+00],
#         [5.20000000e+01],
#         [4.80000000e+01],
#         [1.90000000e+01],
#         [9.20000000e+01],
#         [4.70000000e+01],
#         [4.10000000e+01],
#         [1.10000000e+01],
#         [5.20000000e+01],
#         [5.10000000e+01],
#         [3.30000000e+01],
#         [2.90000000e+01],
#         [2.10000000e+01],
#         [1.50000000e+01],
#         [0.00000000e+00],
#         [7.70000000e+01],
#         [7.00000000e+01],
#         [3.30000000e+01],
#         [9.50000000e+01],
#         [7.60000000e+01],
#         [8.70000000e+01],
#         [9.50000000e+01],
#         [8.00000000e+01],
#         [8.10000000e+01],
#         [5.80000000e+01],
#         [4.60000000e+01],
#         [8.30000000e+01],
#         [2.50000000e+01],
#         [8.90000000e+01],
#         [0.00000000e+00],
#         [3.20000000e+01],
#         [7.70000000e+01],
#         [4.80000000e+01],
#         [8.60000000e+01],
#         [6.00000000e+01],
#         [3.70000000e+01],
#         [4.40000000e+01],
#         [5.90000000e+01],
#         [6.30000000e+01],
#         [4.90000000e+01],
#         [5.50000000e+01]]),
#  array([[ 31.24365589],
#         [  0.282866  ],
#         [ 39.69185252],
#         [ 86.10796637],
#         [ 61.19971596],
#         [ 58.5630564 ],
#         [ 95.78441027],
#         [  5.39884006],
#         [ 78.20296268],
#         [ 44.70786405],
#         [ 96.35659485],
#         [ 58.67366671],
#         [ 72.6356699 ],
#         [ 10.28574844],
#         [ 27.65452669],
#         [ 92.08157084],
#         [ 57.3069783 ],
#         [  8.14815426],
#         [ 93.73176312],
#         [ 39.34482965],
#         [         nan],
#         [ 13.97163653],
#         [ 50.82304924],
#         [101.6228548 ],
#         [ 32.87558963],
#         [ 19.30486546],
#         [ 35.72392691],
#         [ 74.29662112],
#         [ 47.04654956],
#         [ 48.33449605],
#         [  6.70919576],
#         [ 23.87590331],
#         [ 83.78410946],
#         [ 12.31736648],
#         [  6.96753705],
#         [ 10.58213964],
#         [ 86.82132066],
#         [ 32.77049249],
#         [  4.92854619],
#         [  6.96331907],
#         [ 28.22325833],
#         [ 51.92110232],
#         [ 44.46272123],
#         [ 48.03970696],
#         [ 86.26972444],
#         [ 99.00361771],
#         [ 99.11200375],
#         [ 89.91004752],
#         [ 71.30995371],
#         [ 55.85003198],
#         [ 41.88734051],
#         [ 12.12573805],
#         [  9.6168598 ],
#         [ 88.57251713],
#         [ 43.64765048],
#         [ 81.45544709],
#         [ 88.02990531],
#         [ 82.18839247],
#         [ 71.65789964],
#         [ 90.57741298],
#         [  0.70751064],
#         [ 89.55803528],
#         [ 54.14681616],
#         [ 66.16652565],
#         [ 63.64868529],
#         [ 49.65277661],
#         [ 78.67470043],
#         [ 13.89748578],
#         [ 25.26971886],
#         [  8.35936657],
#         [ 21.81267954],
#         [ 75.42283401],
#         [ 53.83020877],
#         [ 19.47100788],
#         [ 79.1050629 ],
#         [ 35.79795462],
#         [ 89.59295492],
#         [ 59.16236621],
#         [ 25.53752833],
#         [ 75.96844763],
#         [ 97.66689567],
#         [ 49.30477253],
#         [ 28.64535198],
#         [ 24.81824269],
#         [ 18.06450222],
#         [ 81.22259156],
#         [ 56.18131518],
#         [ 61.26514581],
#         [ 21.59635575],
#         [102.4959452 ],
#         [ 34.59311043],
#         [ 94.70291077],
#         [ 27.65574228],
#         [ 44.15029394],
#         [ 20.21665898],
#         [ 14.00226297],
#         [ 53.62523007],
#         [ 86.28206739],
#         [ 50.19083844],
#         [ 13.84973988],
#         [ 27.9645947 ],
#         [ 57.05752706],
#         [ 50.5123462 ],
#         [ 49.76948983],
#         [ 61.69900319],
#         [ 66.48278755],
#         [ 82.53030719],
#         [  7.89653984],
#         [ 52.87524074],
#         [  3.57466163],
#         [ 72.60339326],
#         [ 82.69087513],
#         [ 91.64730552],
#         [ 80.80643766],
#         [ 42.29145672],
#         [ 26.78023848],
#         [ 30.48882921],
#         [ 60.02274882],
#         [ 26.33464785],
#         [ 37.83155021],
#         [  9.68240849],
#         [ 26.68273277],
#         [ 86.26936988],
#         [ 89.42222685],
#         [ 41.02251779],
#         [ 98.52008934],
#         [ 56.68718792],
#         [ 32.64997554],
#         [ 46.0537745 ],
#         [ 75.48910307],
#         [ -3.83998112],
#         [ 48.09368034],
#         [ 71.97121038],
#         [ 18.35488924],
#         [ 85.52073551],
#         [ 94.79690531],
#         [ 27.83896261],
#         [ 36.33294447],
#         [ 16.78353974],
#         [ 24.34226432],
#         [ 90.72048818],
#         [  1.10068669],
#         [ 32.46387493],
#         [ 45.09439571],
#         [ 47.5775361 ],
#         [ 73.68477876],
#         [ 86.79002254],
#         [ 14.10999096],
#         [ 78.74139764],
#         [  1.91951333],
#         [ 42.33151664],
#         [ 57.95782956],
#         [ 81.4281205 ],
#         [  5.99606961],
#         [ 10.78089683],
#         [ 53.65084683],
#         [ 58.750127  ],
#         [ 64.43231595],
#         [ 55.35893915],
#         [ 42.63227697],
#         [ 48.97302037],
#         [ 44.98103442],
#         [ 48.79647071],
#         [ 68.4739206 ],
#         [ 45.12420809],
#         [ 76.47340872],
#         [ 49.21863516],
#         [ 71.0826803 ],
#         [ 69.04377173],
#         [ 23.77154623],
#         [ 86.18822311],
#         [ 20.87391785],
#         [ 73.83637687],
#         [ 63.67348242],
#         [ 53.60562216],
#         [ 80.50445387],
#         [ 47.46446305],
#         [ 11.87964573],
#         [ 50.05636123],
#         [ 21.96033347],
#         [ 89.80545367],
#         [ 52.82390762],
#         [ 75.30033002],
#         [ 50.5921991 ],
#         [ 69.02934339],
#         [  8.45252016],
#         [ 94.15149206],
#         [ 49.82634062],
#         [ 22.21908523],
#         [ 61.14568518],
#         [ 80.7633986 ],
#         [ 52.51703683],
#         [ 26.68794368],
#         [ 87.22059677],
#         [ 29.34092408],
#         [ 75.45758614],
#         [ 44.26800515],
#         [ 29.76846185],
#         [ 20.10741433],
#         [ 97.19448821],
#         [  5.8099468 ],
#         [ 90.50155298],
#         [ 30.23177607],
#         [ 41.39990349],
#         [ 79.22021816],
#         [ 41.25155632],
#         [ 11.85312574],
#         [ 19.02332876],
#         [ 88.64183756],
#         [ 47.2492425 ],
#         [ 71.61010303],
#         [ 46.87654473],
#         [ 11.29627199],
#         [ 73.5964342 ],
#         [ 34.07278254],
#         [ 95.2389253 ],
#         [ 94.63911256],
#         [ 60.14031858],
#         [ 85.59308727],
#         [ 97.02383456],
#         [ 40.95102191],
#         [ 79.20610113],
#         [ 89.4749477 ],
#         [  9.40049758],
#         [ 36.67762733],
#         [ 81.28960746],
#         [ 91.17716423],
#         [ 94.68488281],
#         [ 70.77549842],
#         [ 93.59057024],
#         [ 95.58459518],
#         [ 92.05756378],
#         [ 36.78035027],
#         [ 23.85017475],
#         [ 58.09031476],
#         [  0.32908944],
#         [ 44.04222058],
#         [ 32.59980745],
#         [ 47.38516883],
#         [ 18.56241391],
#         [ 87.36260449],
#         [ 84.99484703],
#         [ 73.51081775],
#         [ 91.17012883],
#         [ 76.88604495],
#         [ 78.38491927],
#         [ 83.28199022],
#         [ 62.03811556],
#         [ 51.02642868],
#         [ 96.18852325],
#         [100.7012737 ],
#         [  5.22575957],
#         [ 17.13551132],
#         [ 88.61672694],
#         [ 86.76845244],
#         [ 21.02469368],
#         [  1.65230909],
#         [ 38.13626679],
#         [ 33.43396307],
#         [ 38.46213684],
#         [ 25.10114067],
#         [ 17.60946242],
#         [ 22.66073682],
#         [ 55.9249564 ],
#         [ 49.72359037],
#         [ 52.26831735],
#         [ 85.23492274],
#         [ 91.85091116],
#         [ 12.65537808],
#         [ 98.6132033 ],
#         [ 86.98450355],
#         [ -0.1218605 ],
#         [ 52.24760027],
#         [ 36.62438077],
#         [ 39.98238856],
#         [ 91.19109623],
#         [ 69.71787806],
#         [ 49.42440876],
#         [  2.28657169],
#         [ 36.59623056],
#         [ 80.86087062],
#         [  8.33565458],
#         [ 71.25634126],
#         [  2.11611303],
#         [ 56.37058203],
#         [ 24.58286902],
#         [ 50.61728392],
#         [ 96.62327888],
#         [ 94.9752655 ],
#         [ 26.22196486],
#         [ 30.5413129 ],
#         [ 29.04466136],
#         [ 55.61421297],
#         [ 42.10140878],
#         [100.0953697 ],
#         [ 46.06629478],
#         [ 36.10893209],
#         [ 82.47683519],
#         [ 86.236707  ],
#         [ 75.0284725 ],
#         [ 75.72605529],
#         [  7.38224417],
#         [  5.86039171],
#         [ 61.69026202],
#         [  7.68202459],
#         [  8.93899055],
#         [ 22.62365422],
#         [ 46.94362684],
#         [ 85.52145453],
#         [ 61.7510743 ],
#         [ 94.47728801],
#         [ 88.47741598],
#         [ 15.56135514],
#         [ 11.23757338],
#         [ 65.84975426],
#         [ 90.5799868 ],
#         [ 72.58929383],
#         [ 66.49546208],
#         [ 86.5069584 ],
#         [ 60.27852322],
#         [ 74.25552425],
#         [ 25.7440243 ],
#         [ 24.61215147],
#         [ 20.02797699],
#         [ 21.21321959],
#         [ 47.0586788 ],
#         [ 10.26712261],
#         [ 32.37576914],
#         [ 25.33323728],
#         [ 24.47387908],
#         [ 14.55896144],
#         [ 21.97388066],
#         [ 48.59717283],
#         [ 17.4618141 ],
#         [ 33.94224862],
#         [ 57.25180153],
#         [ 20.72894979],
#         [ 21.53140009],
#         [ 58.70318693],
#         [ 47.95883341],
#         [ 83.88427405],
#         [  3.77820991],
#         [ 50.50711779],
#         [ 65.0132736 ],
#         [ 61.18044414],
#         [ 94.2963344 ],
#         [ 87.67388681],
#         [ 54.57648371],
#         [ 17.33681562],
#         [ 46.78357742],
#         [ 72.95331671],
#         [ 18.40919388],
#         [ 92.01203405],
#         [101.7003412 ],
#         [ 26.59436195],
#         [ 43.30022747],
#         [ 50.02897927],
#         [ 77.83354439],
#         [ 52.73389794],
#         [ 94.36778957],
#         [ -2.23587985],
#         [ 19.42637541],
#         [ 74.12151511],
#         [ 69.35848388],
#         [ 21.10794636],
#         [ 46.14941984],
#         [ 22.5453232 ],
#         [ 96.04932416],
#         [ 36.4139958 ],
#         [ 72.80457527],
#         [ 15.85414849],
#         [ 59.46383041],
#         [  9.29085626],
#         [ 41.53992729],
#         [ 46.36928662],
#         [ 60.38823085],
#         [ 71.70233156],
#         [ 48.88147608],
#         [ 21.01429422],
#         [ 15.50701184],
#         [ 47.85817542],
#         [ 18.44679787],
#         [ 66.04325304],
#         [ 66.7346608 ],
#         [ 71.1433266 ],
#         [ 32.52179399],
#         [ 25.77161074],
#         [ 56.15934471],
#         [ 36.72396986],
#         [  4.09817744],
#         [ 66.28310437],
#         [ 85.86077871],
#         [ 53.25166165],
#         [ 21.37698317],
#         [ 13.93415049],
#         [ 28.90260209],
#         [100.740897  ],
#         [ 24.34804332],
#         [ 88.0578931 ],
#         [ 33.92561965],
#         [ 89.10409255],
#         [ 94.45211871],
#         [ 73.51136922],
#         [ 31.97989959],
#         [ 45.67562576],
#         [ 43.16133498],
#         [  6.3646157 ],
#         [ 38.07166567],
#         [ 99.98491591],
#         [ 62.55662585],
#         [ 25.80714057],
#         [ 13.11612884],
#         [108.8716183 ],
#         [ 13.53290206],
#         [ 62.15313408],
#         [ 71.30828034],
#         [ 64.00077658],
#         [  9.23085749],
#         [  6.96337197],
#         [  5.29705403],
#         [  7.99807343],
#         [ 28.41453196],
#         [ 36.72823317],
#         [100.5328916 ],
#         [102.4967859 ],
#         [ 95.4609216 ],
#         [ 46.80297244],
#         [ 63.5312572 ],
#         [ 53.98393374],
#         [ 82.88935804],
#         [ 48.84542083],
#         [ 29.6673599 ],
#         [ 86.30177517],
#         [ 77.01988215],
#         [  6.81549128],
#         [ 41.21469904],
#         [ 48.43753838],
#         [ 31.11331895],
#         [ 85.23027975],
#         [  2.31670811],
#         [ 71.11189935],
#         [ 61.92303698],
#         [ 87.00645713],
#         [ 28.36793808],
#         [  9.52643164],
#         [101.1097591 ],
#         [ 67.85169407],
#         [ 62.64931741],
#         [ 45.94511142],
#         [ 22.51016575],
#         [ 34.78561007],
#         [ 82.0763803 ],
#         [ 67.92051286],
#         [ 94.08853397],
#         [ 57.11195136],
#         [ 49.44785426],
#         [  0.3769119 ],
#         [ 48.29491198],
#         [ 40.83182104],
#         [ 26.92832418],
#         [ 36.24807243],
#         [ 91.775467  ],
#         [ 20.38051187],
#         [ 16.49185287],
#         [ 33.22031418],
#         [ 52.94026699],
#         [ 58.59500642],
#         [ 66.27746655],
#         [ 54.40348599],
#         [ 96.49812401],
#         [  4.07577614],
#         [ 16.16712757],
#         [ 86.10708624],
#         [ 94.55203143],
#         [ 85.03295412],
#         [ 37.17063131],
#         [ 46.78108638],
#         [ 42.94274064],
#         [ 83.50570521],
#         [ 87.15690853],
#         [ -0.93689505],
#         [ 53.5825402 ],
#         [ 37.49971096],
#         [ 48.89963951],
#         [ 47.88388961],
#         [ 24.76649193],
#         [  7.459606  ],
#         [ 71.67949917],
#         [ 59.1244888 ],
#         [ 77.13735466],
#         [ 55.32164264],
#         [ 74.04682658],
#         [ 22.59015942],
#         [ 39.45358014],
#         [ 24.5227488 ],
#         [ -1.05327561],
#         [ 60.19925869],
#         [ 61.01858089],
#         [  1.61194747],
#         [ 93.25305499],
#         [100.0158026 ],
#         [ 10.32374866],
#         [ 49.86702787],
#         [ 30.6063167 ],
#         [ 32.34784175],
#         [ 29.19693178],
#         [ 39.40049976],
#         [ 21.54945196],
#         [ 16.01629889],
#         [ 37.69447352],
#         [ 10.240085  ],
#         [  6.806419  ],
#         [ 94.62509374],
#         [ 70.4052055 ],
#         [  7.08132338],
#         [ 47.15960005],
#         [ 24.08498313],
#         [ 67.88603132],
#         [ 94.92329574],
#         [ 10.68453755],
#         [ 55.34529893],
#         [ 47.78165248],
#         [ 17.34557531],
#         [ 86.78316267],
#         [ 48.71787679],
#         [ 43.88314335],
#         [ 11.99017641],
#         [ 52.95305521],
#         [ 51.90142035],
#         [ 34.76441561],
#         [ 26.65566328],
#         [ 19.85174138],
#         [ 17.21865634],
#         [ -3.83665214],
#         [ 76.24503196],
#         [ 66.94758118],
#         [ 35.07467353],
#         [ 92.15749762],
#         [ 77.35135732],
#         [ 87.28898389],
#         [ 94.00291863],
#         [ 75.24148428],
#         [ 78.87097714],
#         [ 62.80064204],
#         [ 45.51171028],
#         [ 78.52505087],
#         [ 25.46292549],
#         [ 84.48045678],
#         [  1.40625441],
#         [ 35.00341078],
#         [ 77.53149541],
#         [ 46.9666961 ],
#         [ 86.12955884],
#         [ 56.99178872],
#         [ 41.14386358],
#         [ 41.57421008],
#         [ 61.2229864 ],
#         [ 62.03190983],
#         [ 52.50336074],
#         [ 56.15303953]]))

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10920/3295613205.py in <module>
#       1 lm = LinearRegression()
# ----> 2 lm.fit(x_train,y_train)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
#     577             out = X, y
#     578
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     969     )
#     970
# --> 971     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     972
#     973     check_consistent_length(X, y)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric)
#     979     """Isolated part of check_X_y dedicated to y validation"""
#     980     if multi_output:
# --> 981         y = check_array(
#     982             y, accept_sparse="csr", force_all_finite=True, ensure_2d=False, dtype=None
#     983         )
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
plt.figure(figsize=(16, 8))
plt.scatter(data['x'],data['y'],c='blue'
)
plt.xlabel("x VALUES")
plt.ylabel("y VALUES")
plt.title("Linear Regression")
plt.show()

# %%
y_predict = lm.predict(x_test)

y_predict
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_10920/2004285431.py in <module>
# ----> 1 y_predict = lm.predict(x_test)
#       2
#       3 y_predict
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1207
#    1208     if not fitted:
# -> 1209         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1210
#    1211
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
y_test
# Out:
# array([[98.50371084],
#        [35.02445799],
#        [68.92139297],
#        [84.21191485],
#        [23.47650968],
#        [73.71434779],
#        [22.1363481 ],
#        [ 1.57658438],
#        [55.32083476],
#        [75.63280796],
#        [74.39517002],
#        [28.99769315],
#        [13.51574749],
#        [24.21914027],
#        [42.91449728],
#        [22.58096241],
#        [52.67003801],
#        [85.02778957],
#        [89.93374342],
#        [-2.8307495 ],
#        [10.76669688],
#        [92.26970059],
#        [31.23212856],
#        [27.3051179 ],
#        [ 9.19995472],
#        [49.92639685],
#        [43.2736092 ],
#        [45.00397413],
#        [62.16675273],
#        [92.59573853],
#        [25.30895192],
#        [ 8.79113989],
#        [83.02772202],
#        [59.24362743],
#        [75.14466308],
#        [26.40362524],
#        [57.07748383],
#        [73.13850045],
#        [91.72960726],
#        [94.97068753],
#        [14.81106804],
#        [52.78130641],
#        [53.26657596],
#        [64.94841088],
#        [51.47649476],
#        [51.70352433],
#        [55.72021356],
#        [57.53887255],
#        [63.61364981],
#        [ 2.26705945],
#        [-1.28631089],
#        [ 7.15645766],
#        [21.13655528],
#        [99.51685756],
#        [14.75305272],
#        [24.63528393],
#        [54.54868046],
#        [95.56065366],
#        [76.92664854],
#        [48.43307886],
#        [43.9367213 ],
#        [63.15189497],
#        [57.87219151],
#        [96.19000542],
#        [83.1286166 ],
#        [11.60499315],
#        [57.72853572],
#        [38.3037698 ],
#        [12.91328547],
#        [99.40394676],
#        [25.04169243],
#        [99.30874567],
#        [39.89606046],
#        [26.03323718],
#        [ 1.62882607],
#        [26.11697543],
#        [24.60323899],
#        [80.59643338],
#        [74.83135003],
#        [ 9.19037568],
#        [68.73365081],
#        [-0.76453763],
#        [64.05710234],
#        [48.38088357],
#        [30.13666408],
#        [17.70677576],
#        [18.91422276],
#        [ 8.48916433],
#        [ 3.82938101],
#        [71.70015848],
#        [12.18441166],
#        [80.23051695],
#        [33.21584226],
#        [43.26595082],
#        [92.85929155],
#        [46.43628318],
#        [71.98020786],
#        [99.04315693],
#        [89.13754963],
#        [94.07428225],
#        [51.20390217],
#        [53.06655757],
#        [28.90055826],
#        [60.53321778],
#        [21.65857739],
#        [88.85523586],
#        [58.37266004],
#        [77.33986001],
#        [21.47982988],
#        [19.62278654],
#        [43.71901164],
#        [10.76675683],
#        [52.52101436],
#        [50.01787825],
#        [57.04310305],
#        [33.30638903],
#        [27.35245439],
#        [13.24991628],
#        [61.94273962],
#        [33.67416   ],
#        [91.24239226],
#        [88.60376995],
#        [70.3188322 ],
#        [31.300416  ],
#        [40.30929858],
#        [ 2.37917248],
#        [70.36836307],
#        [31.15664574],
#        [17.9170699 ],
#        [47.41377893],
#        [36.58639803],
#        [66.09563422],
#        [17.03401999],
#        [99.9566225 ],
#        [ 6.04728669],
#        [33.66194193],
#        [37.36298431],
#        [21.99239907],
#        [ 9.57736857],
#        [ 4.03543025]])

# %%
print(f"Train accuracy {round(lm.score(x_train, y_train) * 100, 2)}%")
print(f"Test accuracy {round(lm.score(x_test, y_predict) * 100, 2)}%")
plt.figure(figsize=(16, 8))
plt.scatter(x_train,y_train, color='red')
plt.plot(x_test,y_predict)
plt.xlabel("x VALUE")
plt.ylabel("y VALUE")
plt.title("Linear Regression")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_10920/3013381007.py in <module>
# ----> 1 print(f"Train accuracy {round(lm.score(x_train, y_train) * 100, 2)}%")
#       2 print(f"Test accuracy {round(lm.score(x_test, y_predict) * 100, 2)}%")
#       3 plt.figure(figsize=(16, 8))
#       4 plt.scatter(x_train,y_train, color='red')
#       5 plt.plot(x_test,y_predict)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     698         from .metrics import r2_score
#     699
# --> 700         y_pred = self.predict(X)
#     701         return r2_score(y, y_pred, sample_weight=sample_weight)
#     702
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1207
#    1208     if not fitted:
# -> 1209         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1210
#    1211
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10920/412797284.py in <module>
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(y_test, y_predict)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     772     -3.0
#     773     """
# --> 774     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     775         y_true, y_pred, multioutput
#     776     )
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      87         the dtype argument passed to check_array.
#      88     """
# ---> 89     check_consistent_length(y_true, y_pred)
#      90     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      91     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
# --> 331         raise ValueError(
#     332             "Found input variables with inconsistent numbers of samples: %r"
#     333             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [140, 350]

# %%
x=10
expectied_y = lm.predict([[x]])[0]
print(f" {x} the expected y is {int(expectied_y)}")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_10920/869203553.py in <module>
#       1 x=10
# ----> 2 expectied_y = lm.predict([[x]])[0]
#       3 print(f" {x} the expected y is {int(expectied_y)}")
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1207
#    1208     if not fitted:
# -> 1209         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1210
#    1211
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
lm.fit(x_train,y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lm.score(x_test,y_test)*100,2)} %")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10920/2303160553.py in <module>
# ----> 1 lm.fit(x_train,y_train)
#       2 y_predict = lm.predict(x_test)
#       3 print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
#       4 print(f"Test accuracy {round(lm.score(x_test,y_test)*100,2)} %")
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
#     577             out = X, y
#     578
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     969     )
#     970
# --> 971     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     972
#     973     check_consistent_length(X, y)
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric)
#     979     """Isolated part of check_X_y dedicated to y validation"""
#     980     if multi_output:
# --> 981         y = check_array(
#     982             y, accept_sparse="csr", force_all_finite=True, ensure_2d=False, dtype=None
#     983         )
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# ~/class-401/linear_regression/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
